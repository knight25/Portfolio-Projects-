# %% [markdown]
# # WEB SCRAPING

# %%
import pandas as pd
url = 'https://en.wikipedia.org/wiki/List_of_largest_companies_by_revenue'

# %%
pd.read_html(url)
# Out:
# [    Rank                   Country  Companies
#  0      1  United States of America         20
#  1      2                     China         13
#  2      3                   Germany          4
#  3      4            United Kingdom          2
#  4      4               Switzerland          2
#  5      4                     Japan          2
#  6      7               Netherlands          1
#  7      7               South Korea          1
#  8      7                    France          1
#  9      7                    Russia          1
#  10     7              Saudi Arabia          1
#  11     7                 Singapore          1
#  12     7                    Taiwan          1,
#     Rank                                     Name                Industry  \
#     Rank                                     Name                Industry
#  0     1                                  Walmart                  Retail
#  1     2                             Saudi Aramco             Oil and gas
# ...

# %%
list_of_dfs = pd.read_html(url)

# %%
list_of_dfs[1]
# Out:
#    Rank                                     Name                Industry  \
#    Rank                                     Name                Industry
# 0     1                                  Walmart                  Retail
# 1     2                             Saudi Aramco             Oil and gas
# 2     3          State Grid Corporation of China             Electricity
# 3     4                                   Amazon                  Retail
# 4     5                                    Vitol             Commodities
# 5     6     China National Petroleum Corporation             Oil and gas
# 6     7          China Petrochemical Corporation             Oil and gas
# 7     8                               ExxonMobil             Oil and gas
# 8     9                                    Apple             Electronics
# 9    10                                    Shell             Oil and gas
# 10   11                       UnitedHealth Group              Healthcare
# ...

# %%
df.to_csv(r'C:\Users\OPEYEMI TOLULOPE\Pictures\Data Analyst Projects\Data Scraping\Largest companies revenue.csv', index = False)
